# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tstep = 6000
fname= 'phi_101_%d.npy' % tstep
X = np.load(fname)
print(X.shape)
# Out:
# (1, 101, 101)

# %%
plt.imshow(X[0])
plt.title('Concentration Field')
plt.colorbar()
plt.show()
